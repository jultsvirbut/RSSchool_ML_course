# %% [markdown]
# You can find dataset description here https://archive.ics.uci.edu/ml/datasets/Student+Performance. Data is in "Data Folder" name "student.zip"

# %% [markdown]
# ## How to complete this assignment

# %% [markdown]
# First download the data and extract two tables from the link above. Then complete 9 graded tasks below, the score is given in brackets. Finally submit the resulting `.ipynb` file to rs-app Auto-test.
# - **Do not delete or rename the variables** given before the inscription '#your code here', they are needed for correct verification.
# - **Do not change the code** in the last Notebook cell, it is required for server side.
# - Your **Notebook must run completely without errors** in order to be graded! Please check everything before submission by going _Cell_ -> _Run All_

# %% [markdown]
# ## Here goes!

# %% [markdown]
# ### Import necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Read the data

# %%
mat = pd.read_csv("student-mat.csv", sep=";")
por = pd.read_csv("student-por.csv", sep=";")

# %% [markdown]
# ### Look at first five rows of table with students math grades. In all other tasks, unless otherwise stated, we use it.

# %%
mat.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
mat.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %% [markdown]
# **Task 1 (0.25 points).** Count number of boys and girls in the dataset.

# %%
mat[mat['sex'] == 'F'].count()[0]
# Out:
# 208

# %%
mat[mat['sex'] == 'F'].shape
# Out:
# (208, 33)

# %%
boys, girls = mat[mat['sex'] == 'M'].count()[0], mat[mat['sex'] == 'F'].shape[0]

# %% [markdown]
# **Task 2 (0.25 points).** Count number of 17 year old students having math grade G3 between 10 and 15 inclusively

# %%
mat[(mat['age'] == 17) & (mat['G3'] <= 15) & (mat['G3'] >= 10)].shape[0]
# Out:
# 59

# %%
students_17_year_old = mat[(mat['age'] == 17) & (mat['G3'] <= 15) & (mat['G3'] >= 10)].shape[0]

# %% [markdown]
# **Task 3 (0.5 points).** List top-10 students having biggest average grade (G1, G2, G3)  in math. Count number of boys from that list.

# %%
top_10_gp = mat.sort_values(by=['G1','G2','G3'], ascending=False).head(10)

# %%
top_10_gp
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 47      GP   M   16       U     GT3       T     4     3    health  services
# 374     MS   F   18       R     LE3       T     4     4     other     other
# 42      GP   M   15       U     GT3       T     4     4  services   teacher
# 110     GP   M   15       U     LE3       A     4     4   teacher   teacher
# 113     GP   M   15       U     LE3       T     4     2   teacher     other
# 286     GP   F   18       U     GT3       T     2     2   at_home   at_home
# 129     GP   M   16       R     GT3       T     4     4   teacher   teacher
# 198     GP   F   17       U     GT3       T     4     4  services   teacher
# 245     GP   M   16       U     GT3       T     2     1     other     other
# 293     GP   F   17       R     LE3       T     3     1  services     other
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 47   ...      4        2      2     1     1      2        4  19  19  20
# 374  ...      5        4      4     1     1      1        0  19  18  19
# 42   ...      4        3      3     1     1      5        2  19  18  18
# 110  ...      5        5      3     1     1      4        6  18  19  19
# 113  ...      3        5      2     1     1      3       10  18  19  19
# 286  ...      4        3      3     1     2      2        5  18  18  19
# 129  ...      3        5      5     2     5      4        8  18  18  18
# 198  ...      4        2      4     2     3      2       24  18  18  18
# 245  ...      4        3      3     1     1      4        6  18  18  18
# 293  ...      3        1      2     1     1      3        6  18  18  18
#
# [10 rows x 33 columns]

# %%
top_10_gp[top_10_gp['sex'] == 'M'].shape[0]
# Out:
# 6

# %%
boys_from_top_10 = top_10_gp[top_10_gp['sex'] == 'M'].shape[0]

# %% [markdown]
# **Task 4 (1 point).** Count mean and standard deviation of absences for students with romantic relationship and access to internet

# %%
mat[(mat['romantic'] == 'yes') & (mat['internet'] == 'yes')].groupby(['romantic', 'internet'])['absences'].mean()[0]
# Out:
# 8.155172413793103

# %%
mat[(mat['romantic'] == 'yes') & (mat['internet'] == 'yes')].groupby(['romantic', 'internet'])['absences'].std()[0]
# Out:
# 11.253292038738948

# %%
mean, std = mat[(mat['romantic'] == 'yes') & (mat['internet'] == 'yes')].groupby(['romantic', 'internet'])['absences'].mean()[0], mat[(mat['romantic'] == 'yes') & (mat['internet'] == 'yes')].groupby(['romantic', 'internet'])['absences'].std()[0]

# %% [markdown]
# **Task 5 (1.5 points).** Count number of students for each existing age. Return list with counts sorted by students age in ascending order.

# %% [markdown]
# Note: On 0 index in list we have number of 15 year old students, on 1st index number of 16 year old students, ...

# %%
mat['age'].value_counts().sort_index().to_list()
# Out:
# [82, 104, 98, 82, 24, 3, 1, 1]

# %%
student_counts_for_each_age = mat['age'].value_counts().sort_index().to_list()

# %% [markdown]
# **Task 6* (2 points).** Find most frequent pair (Fjob, Mjob) of students from math grade table.

# %% [markdown]
# Note 1: Do not take student into account if at least one of parents job name is "other". <br>
# Note 2: Pairs (Fjob: teacher, Mjob: at_home) and (Fjob: at_home, Mjob: teacher) are different and their occurrences should be counted separately.

# %% [markdown]
# Hint: groupby (Fjob, Mjob), count rows, descending sort by count, reset_index, take first row values.

# %%
mat['Fjob'].value_counts()
# Out:
# other       217
# services    111
# teacher      29
# at_home      20
# health       18
# Name: Fjob, dtype: int64

# %%
mat['Mjob'].value_counts()
# Out:
# other       141
# services    103
# at_home      59
# teacher      58
# health       34
# Name: Mjob, dtype: int64

# %%
mat[(mat['Fjob'] != 'other') & (mat['Mjob'] != 'other')].groupby(['Fjob', 'Mjob'])\
.agg('count').sort_values(by='school', ascending=False).head(1).index.values[0]
# Out:
# ('services', 'services')

# %%
mat[(mat['Fjob'] != 'other') & (mat['Mjob'] != 'other')].groupby(['Fjob', 'Mjob']).size().reset_index(name='counts').sort_values(by='counts', ascending=False).head(1)
# Out:
#        Fjob      Mjob  counts
# 9  services  services      43

# %%
father, mother = 'services', 'services'

# %% [markdown]
# **Task 7 (1 point).** Count number of students presenting both in mat and por tables.

# %% [markdown]
# _Note 1_: That's a pity that tables haven't foreign keys for joining together. The uniqueness of the student is determined by the uniqueness of the set of all fields except subject fields (G1, G2, G3). <br>
# _Note 2_: Finally you'd better to come up with table having all student personal information and non-null grades in math ["G1_mat", "G2_mat", "G3_mat"] and ["G1_por", "G2_por", "G3_por"]. Joined dataframe could be helpful for further usage. <br>
# Note 3: probably you would like to use "merge" to avoid duplicating column names from right and left dataframe.

# %%
por
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0    ...      4        3      4     1     1      3        4   0  11  11
# 1    ...      5        3      3     1     1      3        2   9  11  11
# 2    ...      4        3      2     2     3      3        6  12  13  12
# 3    ...      3        2      2     1     1      5        0  14  14  14
# 4    ...      4        3      2     1     2      5        0  11  13  13
# ..   ...    ...      ...    ...   ...   ...    ...      ...  ..  ..  ..
# 644  ...      5        4      2     1     2      5        4  10  11  10
# 645  ...      4        3      4     1     1      1        4  15  15  16
# 646  ...      1        1      1     1     1      5        6  11  12   9
# 647  ...      2        4      5     3     4      2        6  10  10  10
# 648  ...      4        4      1     3     4      5        4  10  11  11
#
# [649 rows x 33 columns]

# %%
mat.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
mat.merge(por, how='inner', on=['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
       'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
       'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
       'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
       'Walc', 'health', 'absences'], suffixes=('_mat','_por'))
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0      GP   M   16       U     LE3       T     2     2     other     other
# 1      GP   M   15       U     GT3       A     2     2     other     other
# 2      GP   M   15       U     GT3       T     4     3   teacher     other
# 3      GP   M   15       U     GT3       T     4     4    health    health
# 4      GP   M   15       U     GT3       T     4     4    health  services
# 5      GP   M   15       R     GT3       T     4     3   teacher   at_home
# 6      GP   M   15       U     LE3       T     3     3     other     other
# 7      GP   M   15       U     LE3       T     4     4   teacher     other
# 8      GP   M   15       U     GT3       T     2     2  services  services
# 9      GP   F   16       U     LE3       T     2     2     other   at_home
# 10     GP   F   15       U     LE3       T     4     3  services  services
# 11     GP   F   16       U     LE3       T     4     3   teacher  services
# 12     GP   M   15       U     GT3       T     4     2     other     other
# 13     GP   F   15       U     GT3       T     1     1     other     other
# 14     GP   F   15       U     GT3       T     4     2     other     other
# 15     GP   M   16       U     GT3       T     4     4  services   teacher
# 16     GP   F   15       U     GT3       A     3     3     other    health
# 17     GP   M   15       U     LE3       T     4     2   teacher     other
# 18     GP   F   15       U     LE3       A     3     4     other     other
# 19     GP   M   16       U     LE3       T     2     1   at_home     other
# 20     GP   F   17       U     GT3       T     4     4     other   teacher
# 21     GP   F   18       R     GT3       T     1     1   at_home     other
# 22     GP   M   17       U     GT3       T     3     3     other     other
# 23     GP   F   17       U     GT3       T     2     4  services  services
# 24     GP   F   17       U     GT3       T     1     1   at_home  services
# 25     GP   M   16       U     GT3       T     2     3     other     other
# 26     GP   M   17       U     GT3       T     4     4  services   teacher
# 27     GP   F   16       U     GT3       T     4     3    health     other
# 28     GP   F   17       R     GT3       T     2     1   at_home  services
# 29     GP   M   17       R     GT3       T     2     1     other     other
# 30     GP   F   17       U     LE3       T     0     2   at_home   at_home
# 31     GP   F   18       U     LE3       T     2     2     other     other
# 32     MS   M   19       R     GT3       T     1     1     other     other
# 33     MS   F   18       U     GT3       T     3     3  services  services
# 34     MS   F   18       U     LE3       T     1     1   at_home  services
# 35     MS   F   17       R     GT3       T     1     2     other  services
# 36     MS   F   17       U     GT3       T     2     2     other   at_home
# 37     MS   F   18       R     LE3       T     4     4     other     other
# 38     MS   M   19       R     GT3       T     1     1     other  services
#
#     ... Dalc Walc  health  absences  G1_mat G2_mat G3_mat G1_por G2_por G3_por
# 0   ...    1    1       3         0      12     12     11     13     12     13
# 1   ...    1    1       3         0      14     16     16     14     14     15
# 2   ...    1    1       1         0      13     14     15     12     13     14
# 3   ...    1    1       5         0      12     15     15     11     12     12
# 4   ...    3    4       5         0       9     11     12     10     11     11
# 5   ...    1    1       5         0      17     16     16     13     14     15
# 6   ...    1    1       2         0       8     10     12     13     12     12
# 7   ...    2    4       5         8      12     12     12     10     11     11
# 8   ...    1    1       1         0       8      8     11      9     10     10
# 9   ...    2    2       5        14      10     10      9     10     11     11
# 10  ...    2    4       2         0      10     10     10     13     12     12
# 11  ...    1    2       1         2      16     15     15     16     15     16
# 12  ...    1    1       3         0      10     10     10     11      9     10
# 13  ...    2    3       4         2       9     10     10     13     12     12
# 14  ...    1    3       1         4      13     14     14     15     15     15
# 15  ...    1    1       4         0      16     17     17     16     16     16
# 16  ...    1    1       4        10      10     11     11     10     10     10
# 17  ...    1    1       3        10      18     19     19     18     17     18
# 18  ...    1    1       1         0       7     10     11     10     11     11
# 19  ...    3    5       5         6      12     13     14      9     10     10
# 20  ...    1    1       4         0      11     11     12     13     13     13
# 21  ...    1    5       4         6       9      8     10     11     10     11
# 22  ...    1    4       4         4       6      5      6     11      9     10
# 23  ...    2    3       5         0      16     17     17     17     18     17
# 24  ...    1    1       3         0       8      8      9     12     11     12
# 25  ...    1    1       3         0      13     14     14     13     12     12
# 26  ...    1    2       5         4      17     15     16     13     13     14
# 27  ...    1    5       2         2      16     16     16     14     14     15
# 28  ...    1    1       3         2      13     11     11     13     13     13
# 29  ...    2    4       5         0       8     12     12     12     12     13
# 30  ...    2    3       2         0      16     15     15     14     14     15
# 31  ...    1    1       2         0       8      8      0     10      9     12
# 32  ...    3    3       5         4       8      8      8      8      9     10
# 33  ...    1    1       5         0      10      9      9     10     10     10
# 34  ...    1    1       4         0      18     16     16     19     17     18
# 35  ...    1    2       3         0      12     11     12     13     13     13
# 36  ...    1    1       3         8      13     11     11     10     11     12
# 37  ...    1    1       1         0      19     18     19     15     17     17
# 38  ...    1    3       5         0       6      5      0      5      8      0
#
# [39 rows x 36 columns]

# %%
both_present = mat.merge(por, how='inner', on=['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
       'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
       'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
       'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
       'Walc', 'health', 'absences'], suffixes=('_mat','_por')).shape[0]

# %% [markdown]
# **Task 8 (1.5 points).** Find absolute differences between average mat and por student final grades for each school (GP & MS)

# %%
mat.groupby('school')['G3'].mean()
# Out:
# school
# GP    10.489971
# MS     9.847826
# Name: G3, dtype: float64

# %%
mat.groupby('school')['G3'].mean()['GP']
# Out:
# 10.489971346704872

# %%
abs(mat.groupby('school')['G3'].mean()['GP'] - por.groupby('school')['G3'].mean()['GP'])
# Out:
# 2.0868608045953643

# %%
por.groupby('school')['G3'].mean()
# Out:
# school
# GP    12.576832
# MS    10.650442
# Name: G3, dtype: float64

# %%
GP_diff, MS_diff = abs(mat.groupby('school')['G3'].mean()['GP'] - por.groupby('school')['G3'].mean()['GP']), abs(mat.groupby('school')['G3'].mean()['MS'] - por.groupby('school')['G3'].mean()['MS'])

# %% [markdown]
# **Task 9* (2 points).** Find top-5 linearly dependent pairs of numeric student features from mat table.

# %% [markdown]
# _Note 1_: Use absolute Peason correlation value for measuring the linear relationship between features.

# %% [markdown]
# Correlation coefficients are used in statistics to measure how strong a relationship is between two variables. There are several types of correlation coefficients, but the most popular is Pearson’s. It can take value from -1 to 1 inclusive.
#  - A correlation coefficient of 1 means that for every positive increase in one variable, there is a positive increase of a fixed proportion in the other. For example, shoe sizes go up in (almost) perfect correlation with foot length.
#  - A correlation coefficient of -1 means that for every positive increase in one variable, there is a negative decrease of a fixed proportion in the other. For example, the amount of gas in a tank decreases in (almost) perfect correlation with speed.
#  - Zero means that for every increase of one variable we do not expect always increase or decrease of another variable. It is not a proof, that variables are not related with each other. That only means NO LINEAR relationship between them. Suppose we have variables x and y connected by a sinusoidal law $y=sin(x)$. There is obvious no linear relationship between them (for $x \in [0, \frac{\pi}{2}]$ y increases unevenly ant later for $x \in [\frac{\pi}{2}, \pi]$ y decreases unevenly). Even though they relate to each other by more complex law.
#
# More mathematical explanation https://en.wikipedia.org/wiki/Correlation_and_dependence.

# %%
# Just a short example
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

x = np.array(np.arange(0, 314, 10)) / 100
y1 = -x + 10
y2 = np.sin(x)

fig, (ax1, ax2) = plt.subplots(2, 1)
ax1.scatter(x, -x + 10)
ax1.set_title("Pearson correlation coefficient for variables x and y=(-x + 10) is %.2f. Negative correlation."
      % np.corrcoef(x, y1)[0][1])
ax1.set_xlabel("X")
ax1.set_ylabel("Y =-X + 10")
ax2.scatter(x, y2)
ax2.set_title("Pearson correlation coefficient for variables x and y=sin(x) is %.2f. No correlation."
      % np.corrcoef(x, y2)[0][1])
ax2.set_xlabel("X")
ax2.set_ylabel("Y =sin(X)")

plt.subplots_adjust(hspace=1.0)
plt.show()

# %% [markdown]
# _Note 2_: Use Pandas _.corrcoef_  for calculating Pearson correlation https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.corr.html. Return list of lists of column name pairs by absolute correlation value in descending order. Each pair of names should follow the alphabet order.

# %%
corr_df = mat.corr(method='pearson').abs().unstack().sort_values(ascending=False)

# %%
mat.corr(method='pearson').abs().unstack().sort_values(ascending=False)
# Out:
# G3          G3            1.000000
# G2          G2            1.000000
# Medu        Medu          1.000000
# Fedu        Fedu          1.000000
# traveltime  traveltime    1.000000
#                             ...
# famrel      Medu          0.003914
# Fedu        Dalc          0.002386
# Dalc        Fedu          0.002386
# Fedu        famrel        0.001370
# famrel      Fedu          0.001370
# Length: 256, dtype: float64

# %%
corr_df[corr_df != 1]
# Out:
# G2      G3        0.904868
# G3      G2        0.904868
# G2      G1        0.852118
# G1      G2        0.852118
#         G3        0.801468
#                     ...
# famrel  Medu      0.003914
# Fedu    Dalc      0.002386
# Dalc    Fedu      0.002386
# Fedu    famrel    0.001370
# famrel  Fedu      0.001370
# Length: 240, dtype: float64

# %%
corr_df = corr_df[corr_df != 1].drop_duplicates()

# %%
corr_df
# Out:
# G2          G3        0.904868
#             G1        0.852118
# G1          G3        0.801468
# Dalc        Walc      0.647544
# Medu        Fedu      0.623455
#                         ...
# traveltime  health    0.007501
# studytime   age       0.004140
# Medu        famrel    0.003914
# Fedu        Dalc      0.002386
#             famrel    0.001370
# Length: 120, dtype: float64

# %%
corr_df.sort_index()
# Out:
# Dalc        G2          0.064120
#             Walc        0.647544
#             absences    0.111908
#             age         0.131125
#             famrel      0.077594
#                           ...
# traveltime  G3          0.117142
#             Medu        0.171639
#             age         0.070641
#             failures    0.092239
#             health      0.007501
# Length: 120, dtype: float64

# %%
top5_correlations = [['G2','G3'],['G1','G2'],['G1','G3'],['Dalc', 'Walc'],['Fedu', 'Medu']]

# %% [markdown]
# **Task 10 (bonus no grading).** Plot 5 scatterplots showing relationship between most correlated pairs of variables from the previous task.

# %% [markdown]
# ### Warning! Do not change anything in this area.

# %%
with open('student_answers.txt', 'w') as file:
    file.write(f"{boys} {girls}\n")
    file.write(f"{students_17_year_old}\n")
    file.write(f"{boys_from_top_10}\n")
    file.write(f"{round(mean, 3)} {round(std, 3)}\n")
    file.write(f"{student_counts_for_each_age}\n")
    file.write(f"{father} {mother}\n")
    file.write(f"{both_present}\n")
    file.write(f"{round(GP_diff, 3)} {round(MS_diff, 3)}\n")
    file.write(f"{top5_correlations}")
